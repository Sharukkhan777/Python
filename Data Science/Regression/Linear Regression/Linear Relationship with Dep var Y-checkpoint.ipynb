# %% [markdown]
# # Find Linear Relationship Using sns

# %% [raw]
# Contents:
# 1) Heatmap
# 2) Pairplot
# 3) Custom Function to Extract variables
# 4) Hypothesis and p-value Method

# %% [markdown]
# # 1) Heatmap

# %% [markdown]
# ### Import dataset

# %%
import plotly.express as px
data = px.data.tips()

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
sns.heatmap(data.corr(), 
            annot=True,          # with numbers
            square=True,         # square figure (not necessary)
            vmin= -1,            # vmin is correlation minimum value
            vmax = 1)            # vmax is correlation maximum value

# %% [markdown]
# # 2) Pairplot

# %%
sns.pairplot(data)

# %%
data.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# # 3) Custom function ot Extract Relationship Variables

# %%
# take the X variable with min and max correlation

def extract_linear_var_with_minmax_corr_values(dependent_var,data,min_corr_beyond,max_corr_beyond):
    """
    dependent_var = "tip"
    data = data
    min_corr_beyond = -0.9
    max_corr_beyond = 0.9
    
    return the result in dataframe format
    
    """
    # take one column Y
    df = data.corr()
    df_Y = df[dependent_var]
    lst_name = []
    lst_corr_val = []
    for i in range(len(df_Y)):
        if df_Y.index[i] == dependent_var:
            pass
        else:
            val = df_Y[i]
            if val<= min_corr_beyond or val>=max_corr_beyond:
                lst_name.append(df_Y.index[i])
                lst_corr_val.append(df_Y[i])
    # create a dataframe
    import pandas as pd
    data_f = pd.DataFrame({"For Dep Var '"+str(dependent_var)+"' the correlation beyond "+str(min_corr_beyond)+" and "+str(max_corr_beyond):lst_name,
                         "Correlation Value":lst_corr_val})
    return data_f

# %%
extract_linear_var_with_minmax_corr_values('tip',data,-0.4,0.4)
# Out:
#   For Dep Var 'tip' the correlation beyond -0.4 and 0.4  Correlation Value
# 0                                            total_bill           0.675734
# 1                                                  size           0.489299

# %% [markdown]
# # Hypothesis test and p-value

# %%
# necessary Imports
import pandas as pd
import matplotlib.pyplot as plt
import pickle

data = pd.read_csv('Advertising.csv') # Reading the data file
data.head() # checking the first five rows from the dataset
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
import statsmodels.formula.api as smf
lm = smf.ols(formula='sales ~ TV + radio + newspaper', data=data).fit()

# %%
lm.pvalues # Null hypothesis: there is no relationship between 
           # corresponding X variable and Y variable
           # p-values = Probability of accepting null hypothesis
           # if p-value is less relation is high.
# Out:
# Intercept    1.267295e-17
# TV           1.509960e-81
# radio        1.505339e-54
# newspaper    8.599151e-01
# dtype: float64

# %%
# in scatter plot we can relate to p_value

fig, axs = plt.subplots(1, 3, sharey=True)
data.plot(kind='scatter', x='TV', y='sales', ax=axs[0], figsize=(16, 8))
data.plot(kind='scatter', x='radio', y='sales', ax=axs[1])
data.plot(kind='scatter', x='newspaper', y='sales', ax=axs[2])
